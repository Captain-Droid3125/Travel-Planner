# %%
# %pip install langgraph langchain openai dotenv requests
# Out:
# Requirement already satisfied: langgraph in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (0.5.1)
# Requirement already satisfied: langchain in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (0.3.26)
# Requirement already satisfied: openai in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (1.93.0)
# Requirement already satisfied: dotenv in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (0.9.9)
# Requirement already satisfied: requests in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (2.32.4)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph) (0.3.68)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph) (2.1.0)
# Requirement already satisfied: langgraph-prebuilt<0.6.0,>=0.5.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph) (0.5.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph) (0.1.72)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.18)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from requests) (2025.6.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langchain-core>=0.1->langgraph) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: greenlet>=1 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.16.0)
# Requirement already satisfied: python-dotenv in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from dotenv) (1.1.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: colorama in c:\users\aryan.dhull\onedrive - accenture\desktop\langgraph\env\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show langgraph langchain openai dotenv requests
# Out:
# Name: langgraph
# Version: 0.5.1
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page:
# Author:
# Author-email:
# License-Expression: MIT
# Location: c:\Users\aryan.dhull\OneDrive - Accenture\Desktop\LangGraph\env\Lib\site-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, pydantic, xxhash
# Required-by:
# ---
# Name: langchain
# Version: 0.3.26
# Summary: Building applications with LLMs through composability
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: c:\Users\aryan.dhull\OneDrive - Accenture\Desktop\LangGraph\env\Lib\site-packages
# Requires: langchain-core, langchain-text-splitters, langsmith, pydantic, PyYAML, requests, SQLAlchemy
# Required-by:
# ---
# Name: openai
# Version: 1.93.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: c:\Users\aryan.dhull\OneDrive - Accenture\Desktop\LangGraph\env\Lib\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by: langchain-openai
# ---
# Name: dotenv
# Version: 0.9.9
# Summary: Deprecated package
# Home-page: https://github.com/pedroburon/dotenv
# Author: Pedro Burón
# Author-email: pedroburonv@gmail.com
# License: UNKNOWN
# Location: c:\Users\aryan.dhull\OneDrive - Accenture\Desktop\LangGraph\env\Lib\site-packages
# Requires: python-dotenv
# Required-by:
# ---
# Name: requests
# Version: 2.32.4
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\Users\aryan.dhull\OneDrive - Accenture\Desktop\LangGraph\env\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: jupyterlab_server, langchain, langsmith, requests-toolbelt, tiktoken
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# MODEL

# %%
from model import GroqChatModel
model = GroqChatModel()

# %%
# Test model setup
response = model.invoke("Say hello to the world in a friendly way.")
print("✅ Model response:")
print(response.content)
# Out:
# ✅ Model response:
# Hello there! *big smile* It's so wonderful to meet you! I hope you're having an amazing day, and that life is treating you with kindness and joy. I'm thrilled to be a part of your day, even if it's just for a quick hello! Can't wait to chat with you and see what adventures we can have together!

# %% [markdown]
# STATE

# %%
from typing import TypedDict, Annotated
from langgraph.graph.message import add_messages
import operator

# Define the state for the travel planner application
class TravelPlannerState(TypedDict):
    destination: str
    budget: int
    flights: list[str]
    hotels: list[str]
    activities: list[str]
    include_hotels: bool
    messages: Annotated[list, add_messages]
    step_count: Annotated[int, operator.add]

# %% [markdown]
# NODES AND EDGES

# %%
from langgraph.graph import StateGraph, START, END
from IPython.display import Image

# %%
def add_destination_node(state: TravelPlannerState) -> TravelPlannerState: # type: ignore
    """Node to set travel destination and budget."""
    print("🌍 Welcome to the Travel Planner!")

    destination = input("Enter your travel destination: ")
    budget = int(input("Enter your budget for the trip: "))
    hotel_needed = input("Do you need hotels? (yes/no): ").strip().lower() == "yes"

    print(f"🎯 Setting destination to: {destination}")
    print(f"💰 Setting budget to: {budget}")
    if hotel_needed:
        include_hotels = True
        print("Hotels will be included in the search.")
    else:
        include_hotels = False
        print("Hotels will not be included in the search.")
    

    return {
        "destination": destination,
        "budget": budget,
        "include_hotels": include_hotels,
        "messages": [f"Destination set to {destination} with a budget of {budget}."],
        "step_count": 1
    }

# %%
def search_flights_node(state: TravelPlannerState) -> TravelPlannerState:
    """Node to search for flights based on destination"""
    destination = state.get("destination", "Unknown")
    response = model.invoke(f"List exactly 3 flight options to {destination} with prices. Format each as: 'Airline to {destination} - $price'. Only return the 3 lines, nothing else.")
    flights = [line.strip() for line in response.content.strip().split('\n') if line.strip() and '$' in line]
    
    print(f"✈️ Found {len(flights)} flights to {destination}")
    
    return {
        "flights": flights,
        "messages": [f"Found {len(flights)} flights to {destination}"],
        "step_count":1
    }

# %%
def search_hotels_node(state: TravelPlannerState) -> TravelPlannerState:
    """Node to search for hotels"""
    destination = state.get("destination", "Unknown")
    response = model.invoke(f"List exactly 3 hotel options in {destination} with prices per night. Format each as: 'Hotel Name in {destination} - $price/night'. Only return the 3 lines, nothing else.")
    hotels = [line.strip() for line in response.content.strip().split('\n') if line.strip() and '$' in line]
    
    print(f"🏨 Found {len(hotels)} hotels in {destination}")
    
    return {
        "hotels": hotels,
        "messages": [f"Found {len(hotels)} hotels in {destination}"],
        "step_count": 1
    }

# %%
def plan_activities_node(state: TravelPlannerState) -> TravelPlannerState:
    """Node to plan activities"""
    destination = state.get("destination", "Unknown")
    response = model.invoke(f"List exactly 3 tourist activities in {destination}. One activity per line. Only return the 3 activity names, nothing else.")
    activities = [line.strip() for line in response.content.strip().split('\n') if line.strip() and len(line.strip()) > 5]
    
    print(f"🎭 Planned {len(activities)} activities for {destination}")
    
    return {
        "activities": activities,
        "messages": [f"Planned {len(activities)} activities"],
        "step_count": 1
    }

# %%
def branch_after_destination(state):
        # If want_hotels is True, go to both flights and hotels in parallel
        # If want_hotels is False, only go to search_flights
        if state.get("include_hotels", True):
            return "flights_and_hotels"
        else:
            return "flights_only"

# %%
def flights_and_hotels_router(state):
    return state

# %%
def summarize_plan_node(state: TravelPlannerState) -> TravelPlannerState: # type: ignore
    """Final node to summarize the travel plan"""
    destination = state.get("destination", "Unknown")

    total_steps = state.get("step_count", 0)
    
    summary = f"""
    📋 TRAVEL PLAN SUMMARY for {destination}:
    ✈️ Flights: {len(state.get('flights', []))} options
    🏨 Hotels: {len(state.get('hotels', []))} options  
    🎭 Activities: {len(state.get('activities', []))} planned
    📊 Total processing steps: {total_steps}
    """
    
    print(summary)

    return {
        "messages": [summary],
        "step_count": 1
    }

# %%
def create_travel_planner_graph():
    """Create and configure the LangGraph workflow"""
    
    # Initialize the graph with our state schema
    workflow = StateGraph(TravelPlannerState) # type: ignore
    workflow.name = "Travel Planner Workflow"

    # Defining the nodes in the workflow
    workflow.add_node("add_destination", add_destination_node)
    workflow.add_node("flights_and_hotels_router", flights_and_hotels_router)
    workflow.add_node("plan_activities", plan_activities_node)
    workflow.add_node("search_flights", search_flights_node)
    workflow.add_node("search_hotels", search_hotels_node)
    workflow.add_node("summarize", summarize_plan_node)
    

    # Adding edges to connect the nodes
    workflow.add_edge(START, "add_destination")

    # #Parallel execution of flight and hotel searches
    # workflow.add_edge("add_destination", "search_flights")
    # workflow.add_edge("add_destination", "search_hotels")
    
    # Conditional branching based on whether hotels are included
    workflow.add_conditional_edges(
        "add_destination",
        branch_after_destination,
        {
            "flights_and_hotels": "flights_and_hotels_router",
            "flights_only": "search_flights"
        }
    )

    workflow.add_edge("flights_and_hotels_router", "search_flights")
    workflow.add_edge("flights_and_hotels_router", "search_hotels")
    workflow.add_edge("flights_and_hotels_router", "plan_activities")  

    # If only flights, plan_activities must still run
    workflow.add_edge("search_flights", "plan_activities")

    # All paths converge to summarize
    workflow.add_edge("search_flights", "summarize")
    workflow.add_edge("search_hotels", "summarize")
    workflow.add_edge("plan_activities", "summarize")

    workflow.add_edge("summarize", END)

    return workflow

# %%
if __name__ == "__main__":
    print("🚀 Creating LangGraph Travel Planner...")
    
    # Create the graph
    travel_app = create_travel_planner_graph().compile()
    
    # Initial state
    initial_state = {
        "destination": "",
        "budget": 0,
        "flights": [],
        "hotels": [],
        "activities": [],
        "include_hotels": True,  # Default to including hotels
        "messages": [],
        "step_count": 0
    }
    
    print("\n📊 INITIAL STATE STRUCTURE:")
    for key, value in initial_state.items():
        print(f"  {key}: {type(value).__name__} = {value}")
    
    print("\n" + "="*50)
    print("🔄 EXECUTING LANGGRAPH WORKFLOW...")
    print("="*50)
    
    # Run the workflow
    final_state = travel_app.invoke(initial_state)
    
    print("\n" + "="*50)
    print("📊 FINAL STATE STRUCTURE:")
    print("="*50)
    for key, value in final_state.items():
        if key == "messages":
            print(f"  {key}: {len(value)} messages")
            for i, msg in enumerate(value, 1):
                print(f"    {i}. {msg}")
        elif isinstance(value, list):
            print(f"  {key}: {len(value)} items")
            for item in value:
                print(f"    - {item}")
        else:
            print(f"  {key}: {value}")
    
    print(f"\n✅ Workflow completed with {final_state['step_count']} total steps")
# Out:
# 🚀 Creating LangGraph Travel Planner...
#
# 📊 INITIAL STATE STRUCTURE:
#   destination: str =
#   budget: int = 0
#   flights: list = []
#   hotels: list = []
#   activities: list = []
#   include_hotels: bool = True
#   messages: list = []
#   step_count: int = 0
#
# ==================================================
# 🔄 EXECUTING LANGGRAPH WORKFLOW...
# ==================================================
# 🌍 Welcome to the Travel Planner!
# 🎯 Setting destination to: Vietnam
# 💰 Setting budget to: 3000
# Hotels will be included in the search.
# 🎭 Planned 4 activities for Vietnam
# ✈️ Found 3 flights to Vietnam
# 🏨 Found 3 hotels in Vietnam
#
#     📋 TRAVEL PLAN SUMMARY for Vietnam:
#     ✈️ Flights: 3 options
#     🏨 Hotels: 3 options
#     🎭 Activities: 4 planned
#     📊 Total processing steps: 5
#
# 🎭 Planned 4 activities for Vietnam
#
#     📋 TRAVEL PLAN SUMMARY for Vietnam:
#     ✈️ Flights: 3 options
#     🏨 Hotels: 3 options
#     🎭 Activities: 4 planned
#     📊 Total processing steps: 7
#
#
# ==================================================
# 📊 FINAL STATE STRUCTURE:
# ==================================================
#   destination: Vietnam
#   budget: 3000
#   flights: 3 items
#     - Qantas to Vietnam - $550
#     - Thai Airways to Vietnam - $400
#     - Singapore Airlines to Vietnam - $450
#   hotels: 3 items
#     - The Reverie Saigon - $100/night
#     - Pullman Saigon Centre - $80/night
#     - Hanoi La Siesta Hotel & Spa - $50/night
#   activities: 4 items
#     - Here are 3 tourist activities in Vietnam:
#     - Ha Long Bay Cruise
#     - Cycling through Hoi An's Countryside
#     - Hiking in Sapa's Mountains
#   include_hotels: True
#   messages: 7 messages
#     1. content='Destination set to Vietnam with a budget of 3000.' additional_kwargs={} response_metadata={} id='afefd01d-f5b0-4b7b-b5c9-7341b6271ea4'
#     2. content='Planned 4 activities' additional_kwargs={} response_metadata={} id='426f4fb9-86f3-42d7-b346-a33fb6f6b2a7'
#     3. content='Found 3 flights to Vietnam' additional_kwargs={} response_metadata={} id='c37fadea-5dd5-4f1b-9035-d8752af017d5'
#     4. content='Found 3 hotels in Vietnam' additional_kwargs={} response_metadata={} id='f6040ddc-c42f-412e-84b8-4181ed4e359b'
#     5. content='Planned 4 activities' additional_kwargs={} response_metadata={} id='54901f14-f22b-47d7-beb8-a7cb14a0270b'
#     6. content='\n    📋 TRAVEL PLAN SUMMARY for Vietnam:\n    ✈️ Flights: 3 options\n    🏨 Hotels: 3 options  \n    🎭 Activities: 4 planned\n    📊 Total processing steps: 5\n    ' additional_kwargs={} response_metadata={} id='46446581-6082-46fc-83ce-9ab1394ed059'
#     7. content='\n    📋 TRAVEL PLAN SUMMARY for Vietnam:\n    ✈️ Flights: 3 options\n    🏨 Hotels: 3 options  \n    🎭 Activities: 4 planned\n    📊 Total processing steps: 7\n    ' additional_kwargs={} response_metadata={} id='24cca3ae-5000-477e-a4f5-070474a0e83f'
#   step_count: 8
#
# ✅ Workflow completed with 8 total steps
